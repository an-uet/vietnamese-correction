# %%
from transformers import pipeline
path_to_model = 'models/model'
path_to_model = 'anlt69/bartpho_1'
# path_to_model = 'anlt69/7_epoch'
# path_to_model='anlt69/vietnamese_correction_2'
# path_to_model='anlt69/test'
# path_to_model='models/model_ver03'
corrector = pipeline("text2text-generation", model=path_to_model)

text = 'd3/1d.ap 4xã lê minh xuân, huyện bình chánh, thành phố hồ chí minh'
result = corrector(text.lower(), max_length=128)[0]['generated_text'].strip()
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       3 path_to_model = 'anlt69/bartpho_1'
#       4 # path_to_model = 'anlt69/7_epoch'
#       5 # path_to_model='anlt69/vietnamese_correction_2'
#       6 # path_to_model='anlt69/test'
#       7 # path_to_model='models/model_ver03'
# ----> 8 corrector = pipeline("text2text-generation", model=path_to_model)
#      10 text = 'd3/1d.ap 4xã lê minh xuân, huyện bình chánh, thành phố hồ chí minh'
#      11 result = corrector(text.lower(), max_length=128)[0]['generated_text'].strip()
#
# File ~/anaconda3/envs/gan_model/lib/python3.8/site-packages/transformers/pipelines/__init__.py:999, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
# ...

# %%
# !pip install -q transformers sentencepiece
# Out:
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
from transformers import pipeline # for using model in huggingface

corrector = pipeline("text2text-generation", model="bmd1905/vietnamese-correction")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 from transformers import pipeline # for using model in huggingface
#       3 corrector = pipeline("text2text-generation", model="bmd1905/vietnamese-correction")
#
# ModuleNotFoundError: No module named 'transformers'

# %%
print(corrector("côn viec kin doanh thì rất kho khan nên toi quyết dinh chuyển sang nghề khac  ", max_length=128))
print(corrector("toi dang là sinh diên nam hai ở truong đạ hoc khoa jọc tự nhiên , trogn năm ke tiep toi sẽ chọn chuyen nganh về trí tue nhana tạo", max_length=128))
print(corrector("Tôi  đang học AI ở trun tam AI viet nam  ", max_length=128))
print(corrector("Nhưng sức huỷ divt của cơn bão mitch vẫn chưa thấm vào đâu lsovớithảm hoạ tại Bangladesh ăm 1970 ", max_length=128))
print(corrector("Lần này anh Phươngqyết xếp hàng mua bằng được 1 chiếc", max_length=128))
print(corrector("một số chuyen gia tài chính ngâSn hànG của Việt Nam cũng chung quan điểmnày", max_length=128))
print(corrector("Cac so liệu cho thay ngươi dân viet nam đang sống trong 1 cuôc sóng không duojc nhu mong đọi", max_length=128))
print(corrector("Nefn kinh té thé giới đang đúng trươc nguyen co của mọt cuoc suy thoai", max_length=128))
print(corrector("Khong phai tất ca nhưng gi chung ta thấy dideu là sụ that", max_length=128))
print(corrector("chinh phủ luôn cố găng het suc để naggna cao chat luong nền giáo duc =cua nuoc nhà", max_length=128))
print(corrector("nèn kinh te thé giới đang đứng trươc nguy co của mọt cuoc suy thoai", max_length=128))
print(corrector("kinh tế viet nam dang dứng truoc 1 thoi ky đổi mơi chưa tung có tienf lệ trong lịch sử", max_length=128))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 print(corrector("côn viec kin doanh thì rất kho khan nên toi quyết dinh chuyển sang nghề khac  ", max_length=128))
#       2 print(corrector("toi dang là sinh diên nam hai ở truong đạ hoc khoa jọc tự nhiên , trogn năm ke tiep toi sẽ chọn chuyen nganh về trí tue nhana tạo", max_length=128))
#       3 print(corrector("Tôi  đang học AI ở trun tam AI viet nam  ", max_length=128))
#
# NameError: name 'corrector' is not defined
